# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt 
import seaborn as sns
# %matplotlib inline
dataset = pd.read_csv('crime2.csv')
df=dataset
r=0
def estimate_coef(x, y): 
    n = np.size(x) 
    m_x, m_y = np.mean(x), np.mean(y) 
    SS_xy = np.sum(y*x) - n*m_y*m_x 
    SS_xx = np.sum(x*x) - n*m_x*m_x 
    b_1 = SS_xy / SS_xx 
    b_0 = m_y - b_1*m_x  
    return(b_0, b_1)  
def plot_regression_line(x, y, b): 
    plt.scatter(x, y, color = "m", 
               marker = "o", s = 30) 
    y_pred = b[0] + b[1]*x 
    plt.plot(x, y_pred, color = "g")  
    plt.xlabel('x') 
    plt.ylabel('y') 
    plt.show() 
    
class Node:
    def __init__(self, year=None,popu=None,violent=None,murder=None,rape=None,rob=None,assault=None,prop=None,burglary=None,larency=None,motor=None):
        self.year = year
        self.popu = popu
        self.violent = violent
        self.murder = murder
        self.rape = rape
        self.rob = rob
        self.assault = assault
        self.prop = prop
        self.burglary = burglary
        self.larency = larency
        self.motor = motor
        self.nextval = None

class SLinkedList:
    def __init__(self):
        self.headval = None

    def listprint(self):
        printval = self.headval
        while printval is not None:
            print(printval.year,printval.popu,printval.violent,printval.murder,printval.rape,printval.rob,printval.assault,printval.prop,printval.burglary,printval.larency,printval.motor)
            printval = printval.nextval
    
    def AtEnd(self, node):
        NewNode = node
        if self.headval is None:
            self.headval = NewNode
            return
        laste = self.headval
        while(laste.nextval):
            laste = laste.nextval
        laste.nextval=NewNode

list = SLinkedList()

for row in range(0,20):
    node = Node(df.iat[row,0],df.iat[row,1],df.iat[row,2],df.iat[row,3],df.iat[row,4],df.iat[row,5],df.iat[row,6],df.iat[row,7],df.iat[row,8],df.iat[row,9],df.iat[row,10])
    list.AtEnd(node)
def main():
   menu()


def menu():
    #print("**************************")
    print()

    choice = input("""
                      A: TO VIEW THE DATA
                      B: TO FIND THE CORRELATION
                      C: TO FIND THE REGRESSION
                      D:TO SEARCH
                      E:TO SORT
                    

                      Please enter your choice: """)

    if choice == "A" or choice =="a":
        view()
    elif choice == "B" or choice =="b":
        cor()
    elif choice=="C" or choice=="c":
        reg()
    elif choice=="D" or choice=="d":
        search()
    elif choice=="E" or choice=="e":
        sort()
    elif choice=="H" or choice=="h":
        hypo(r)
    else:
        print("You must only select either A or B or C or D or E")
        print("Please try again")
        menu()

def view():
   list.listprint()
def cor():
    a=df[['Year','Population1']].corr()
    print(a)
    b=df[['Population1','violent crime']].corr()
    print(b)
    c=df[['Population1','murder']].corr()
    print(c)
    d=df[['Population1','Rape']].corr()
    print(d)
    e=df[['Population1','Robbery']].corr()
    print(e)
    f=df[['Population1','assault']].corr()
    print(f)
    g=df[['Population1','Property']].corr()
    print(g)
    h=df[['Population1','Burglary']].corr()
    print(h)
    i=df[['Population1','larency']].corr()
    print(i)
    j=df[['Population1','motor']].corr()
    print(j)
def reg():
    n = int(input("enter the year to be predicted:"))
    x = df.iloc[:,0].values
    y = df.iloc[:,2].values
    b = estimate_coef(x, y) 
    print("Estimated coefficients:\na = {} \nb = {}".format(b[0], b[1]))
    plot_regression_line(x, y, b)
    r=b[0]+(n*b[1])
    print(r)
    print("**************************")
    print("the null hypothesis is %f"%(r))
    m=df.loc[:,"violent crime"].mean()
    sd=df.loc[:,"violent crime"].std()
    n=20
    n2=20**0.5
    t=(r-m)/(sd/n2)
    print("we have taken the 5% level of significance")
    print("**************************")
    print("t-table=2.086")
    print("**************************")
    print("the hypothesis value is %f"%(t))
    print("**************************")
    tt=2.086
    if tt>t:
     print("we accept the null hypothesis")
    else:
     print("we reject the null hypothesis")
    x = df.iloc[:,0].values
    y = df.iloc[:,3].values
    b = estimate_coef(x, y) 
    print("Estimated coefficients:\na = {} \nb = {}".format(b[0], b[1]))
    plot_regression_line(x, y, b)
    r=b[0]+(n*b[1])
    print(r)
    print("**************************")
    print("the null hypothesis is %f"%(r))
    m=df.loc[:,"murder"].mean()
    sd=df.loc[:,"murder"].std()
    n=20
    n2=20**0.5
    t=(r-m)/(sd/n2)
    print("we have taken the 5% level of significance")
    print("**************************")
    print("t-table=2.086")
    print("**************************")
    print("the hypothesis value is %f"%(t))
    print("**************************")
    tt=2.086
    if tt>t:
     print("we accept the null hypothesis")
    else:
     print("we reject the null hypothesis")
    x = df.iloc[:,0].values
    y = df.iloc[:,4].values
    b = estimate_coef(x, y) 
    print("Estimated coefficients:\na = {} \nb = {}".format(b[0], b[1]))
    plot_regression_line(x, y, b)
    r=b[0]+(n*b[1])
    print(r)
    print("**************************")
    print("the null hypothesis is %f"%(r))
    m=df.loc[:,"Rape"].mean()
    sd=df.loc[:,"Rape"].std()
    n=20
    n2=20**0.5
    t=(r-m)/(sd/n2)
    print("we have taken the 5% level of significance")
    print("**************************")
    print("t-table=2.086")
    print("**************************")
    print("the hypothesis value is %f"%(t))
    print("**************************")
    tt=2.086
    if tt>t:
     print("we accept the null hypothesis")
    else:
     print("we reject the null hypothesis")
    x = df.iloc[:,0].values
    y = df.iloc[:,5].values
    b = estimate_coef(x, y) 
    print("Estimated coefficients:\na = {} \nb = {}".format(b[0], b[1]))
    plot_regression_line(x, y, b)
    r=b[0]+(n*b[1])
    print(r)
    print("**************************")
    print("the null hypothesis is %f"%(r))
    m=df.loc[:,"Robbery"].mean()
    sd=df.loc[:,"Robbery"].std()
    n=20
    n2=20**0.5
    t=(r-m)/(sd/n2)
    print("we have taken the 5% level of significance")
    print("**************************")
    print("t-table=2.086")
    print("**************************")
    print("the hypothesis value is %f"%(t))
    print("**************************")
    tt=2.086
    if tt>t:
     print("we accept the null hypothesis")
    else:
     print("we reject the null hypothesis")
    x = df.iloc[:,0].values
    y = df.iloc[:,6].values
    b = estimate_coef(x, y) 
    print("Estimated coefficients:\na = {} \nb = {}".format(b[0], b[1]))
    plot_regression_line(x, y, b)
    r=b[0]+(n*b[1])
    print(r)
    print("**************************")
    print("the null hypothesis is %f"%(r))
    m=df.loc[:,"assault"].mean()
    sd=df.loc[:,"assault"].std()
    n=20
    n2=20**0.5
    t=(r-m)/(sd/n2)
    print("we have taken the 5% level of significance")
    print("**************************")
    print("t-table=2.086")
    print("**************************")
    print("the hypothesis value is %f"%(t))
    print("**************************")
    tt=2.086
    if tt>t:
     print("we accept the null hypothesis")
    else:
     print("we reject the null hypothesis")
    x = df.iloc[:,0].values
    y = df.iloc[:,7].values
    b = estimate_coef(x, y) 
    print("Estimated coefficients:\na = {} \nb = {}".format(b[0], b[1]))
    plot_regression_line(x, y, b)
    r=b[0]+(n*b[1])
    print(r)
    print("**************************")
    print("the null hypothesis is %f"%(r))
    m=df.loc[:,"Property"].mean()
    sd=df.loc[:,"Property"].std()
    n=20
    n2=20**0.5
    t=(r-m)/(sd/n2)
    print("we have taken the 5% level of significance")
    print("**************************")
    print("t-table=2.086")
    print("**************************")
    print("the hypothesis value is %f"%(t))
    print("**************************")
    tt=2.086
    if tt>t:
     print("we accept the null hypothesis")
    else:
     print("we reject the null hypothesis")
    x = df.iloc[:,0].values
    y = df.iloc[:,8].values
    b = estimate_coef(x, y) 
    print("Estimated coefficients:\na = {} \nb = {}".format(b[0], b[1]))
    plot_regression_line(x, y, b)
    r=b[0]+(n*b[1])
    print(r)
    print("**************************")
    print("the null hypothesis is %f"%(r))
    m=df.loc[:,"Burglary"].mean()
    sd=df.loc[:,"Burglary"].std()
    n=20
    n2=20**0.5
    t=(r-m)/(sd/n2)
    print("we have taken the 5% level of significance")
    print("**************************")
    print("t-table=2.086")
    print("**************************")
    print("the hypothesis value is %f"%(t))
    print("**************************")
    tt=2.086
    if tt>t:
     print("we accept the null hypothesis")
    else:
     print("we reject the null hypothesis")
    x = df.iloc[:,0].values
    y = df.iloc[:,9].values
    b = estimate_coef(x, y) 
    print("Estimated coefficients:\na = {} \nb = {}".format(b[0], b[1]))
    plot_regression_line(x, y, b)
    r=b[0]+(n*b[1])
    print(r)
    print("**************************")
    print("the null hypothesis is %f"%(r))
    m=df.loc[:,"larency"].mean()
    sd=df.loc[:,"larency"].std()
    n=20
    n2=20**0.5
    t=(r-m)/(sd/n2)
    print("we have taken the 5% level of significance")
    print("**************************")
    print("t-table=2.086")
    print("**************************")
    print("the hypothesis value is %f"%(t))
    print("**************************")
    tt=2.086
    if tt>t:
     print("we accept the null hypothesis")
    else:
     print("we reject the null hypothesis")
    x = df.iloc[:,0].values
    y = df.iloc[:,10].values
    b = estimate_coef(x, y) 
    print("Estimated coefficients:\na = {} \nb = {}".format(b[0], b[1]))
    plot_regression_line(x, y, b)
    r=b[0]+(n*b[1])
    print(r)
    print("**************************")
    print("the null hypothesis is %f"%(r))
    m=df.loc[:,"motor"].mean()
    sd=df.loc[:,"motor"].std()
    n=20
    n2=20**0.5
    t=abs(r-m)/(sd/n2)
    print("we have taken the 5% level of significance")
    print("**************************")
    print("t-table=2.086")
    print("**************************")
    print("the hypothesis value is %f"%(t))
    print("**************************")
    tt=2.086
    if tt>t:
     print("we accept the null hypothesis")
    else:
     print("we reject the null hypothesis")
def search():
        n = int(input("enter the year:"))
        print("The number of voilent crimes in %d are %d"%(n,df.loc[df.Year == n,'violent crime']))
        print("The number of murder in %d are %d"%(n,df.loc[df.Year == n,'murder']))
        print("The number of Rape in %d are %d"%(n,df.loc[df.Year == n,'Rape']))
        print("The number of Robbery in %d are %d"%(n,df.loc[df.Year == n,'Robbery']))
        print("The number of assault in %d are %d"%(n,df.loc[df.Year == n,'assault']))
        print("The number of Property in %d are %d"%(n,df.loc[df.Year == n,'Property']))
        print("The number of Burglary in %d are %d"%(n,df.loc[df.Year == n,'Burglary']))
        print("The number of larency in %d are %d"%(n,df.loc[df.Year == n,'larency']))
        print("The number of motor in %d are %d"%(n,df.loc[df.Year == n,'motor']))
def sort():
    df.sort_values("violent crime", axis = 0, ascending = False, 
                 inplace = True, na_position ='last')
    df.sort_values("murder", axis = 0, ascending = False, 
                 inplace = True, na_position ='last')
    df.sort_values("Rape", axis = 0, ascending = False, 
                 inplace = True, na_position ='last')
    df.sort_values("Robbery", axis = 0, ascending = False, 
                 inplace = True, na_position ='last')
    df.sort_values("assault", axis = 0, ascending = False, 
                 inplace = True, na_position ='last')
    df.sort_values("Property", axis = 0, ascending = False, 
                 inplace = True, na_position ='last')
    df.sort_values("Burglary", axis = 0, ascending = False, 
                 inplace = True, na_position ='last')
    df.sort_values("larency", axis = 0, ascending = False, 
                 inplace = True, na_position ='last')
    df.sort_values("motor", axis = 0, ascending = False, 
                 inplace = True, na_position ='last')
    print(df)
main()
# Out:
#                       A: TO VIEW THE DATA
#                       B: TO FIND THE CORRELATION
#                       C: TO FIND THE REGRESSION
#                       D:TO SEARCH
#                       E:TO SORT
#
#
#                       Please enter your choice: c
# enter the year to be predicted:2017
# Estimated coefficients:
# a = 40579194.166917294
# b = -19550.04060150376
# 1146762.273684211
# **************************
# the null hypothesis is 1146762.273684
# we have taken the 5% level of significance
# **************************
# t-table=2.086
# **************************
# the hypothesis value is -7.168845
# **************************
# we accept the null hypothesis
# Estimated coefficients:
# a = 194156.44436090224
# b = -88.78646616541353
# 192380.71503759397
# **************************
# the null hypothesis is 192380.715038
# we have taken the 5% level of significance
# **************************
# t-table=2.086
# **************************
# ...

# %%
print(df)
# Out:
#     Year  Population1  violent crime  murder   Rape  Robbery  assault  \
# 0   1997    267783607        1636096   18208  96153   498534  1023201
# 1   1998    270248003        1533887   16974  93144   447186   976583
# 2   1999    272690813        1426044   15522  89411   409371   911740
# 3   2000    281421906        1425486   15586  90178   408016   911706
# 4   2001    285317559        1439480   16037  90863   423557   909023
# 5   2002    287973924        1423677   16229  95235   420806   891407
# 6   2003    290788976        1383676   16528  93883   414235   859030
# 7   2004    293656842        1360088   16148  95089   401470   847381
# 8   2005    296507061        1390745   16740  94347   417438   862220
# 9   2006    299398484        1435123   17309  94472   449246   874096
# 10  2007    301621157        1422970   17128  92160   447324   866358
# 11  2008    304059724        1394461   16465  90750   443563   843683
# ...
